# %% [markdown]
# <a href="https://colab.research.google.com/github/nahidame/QuaziNahida.github.io/blob/main/1_Project___Cardio_Good_Fitness__Quazi_Nahida_Sultana_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <b><h2><center>Cardio Good Fitness Project </center></h2></b>

# %% [markdown]
# ### **Description**
#
# ### **Objective**
#
# Explore the dataset to identify differences between the customers of each product : <br>
#
#
#
# > **1.** Come up with a customer profile (characteristics of a customer) of the different products <br>
#  **2.** Based on the analysis generate a set of insights and recommendations that will help the company in targeting new customers. <br><br>

# %% [markdown]
# ### **Data Description:**
#
# The data is about customers of the treadmill product(s) of a retail store called Cardio Good Fitness. It contains the following variables- <br>
#
# > **1.** Product - The model no. of the treadmill <br>
#   **2.** Age -  Age of the customer in no of years <br>
#   **3.** Gender - Gender of the customer<br>
#   **4.** Education - Education of the customer in no. of years <br>
#   **5.** Marital Status - Marital status of the customer <br>
#   **6.** Usage - Avg. # times the customer wants to use the treadmill every week <br>
#   **7.** Fitness - Self rated fitness score of the customer (5 - very fit, 1 - very unfit) <br>
#   **8.** Income - Income of the customer <br>
#   **9.** Miles- Miles that a customer expects to run <br>

# %% [markdown]
# ### **Importing the necessary packages**

# %% [markdown]
# Let's start by importing necessary libraries

# %%
import numpy as np
import pandas as pd

# Libraries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Command to tell Python to actually display the graphs
# %matplotlib inline 
# to restrict the float value to 3 decimal places
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# **Importing the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path="/content/drive/MyDrive/DATA SCIENCE 2022/3- Exploratory Data Analysis/CardioGoodFitness.csv" 
data1=pd.read_csv(path)

# %%
# copying data to another variable to avoid any changes to original data
data = data1.copy()

# %% [markdown]
# ### **Data Overview**

# %% [markdown]
# The initial steps to get an overview of any dataset is to:
# - observe the first few rows of the dataset, to check whether the dataset has been loaded properly or not
# - get information about the number of rows and columns in the dataset
# - find out the data types of the columns to ensure that data is stored in the preferred format and the value of each property is as expected.
# - check the statistical summary of the dataset to get an overview of the numerical columns of the data

# %% [markdown]
# **View the first and last 5 rows of the dataset**

# %%
data.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
data.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# - *The 'Product' column contains the model of treadmill;
# 'Gender' column contains men or female type, 'MaritalStatus' column contains the status of the marriage of the customer*
# - *The 'Age' column has the range of customer who uses the treadmill*
# - *The 'Education' column represent the customer education years*
# - *The 'Usage' column represent the customer use the Tradmill per week and the 'Fitness' column is self scored by the customer*
# - *The 'Miles' column represent the miles customer expect to run*

# %% [markdown]
# **Understand the shape of the dataset**

# %%
data.shape
# Out:
# (180, 9)

# %% [markdown]
# - *The dataset has 180 rows and 9 columns*

# %% [markdown]
# **Checking the data Type**
#
# Checking the data types of the columns for the dataset

# %%
# let's check the data type of columns
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %% [markdown]
# - *All the columns have 180 observations*
# - *The 'Product',  'Gender' and 'MaritalStatus' columns are being read as a 'object' datatype while the rest of the 6 columns are 'numerical/Integer' datatype*

# %%
# Check for any missing value 
data.isnull().sum()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %% [markdown]
# - *There is no missing values in any column*

# %% [markdown]
# **Let's check the count of each unique category in each of the categorical/object and Integer type variables.**

# %%
list_col=['Product', 'Gender', 'MaritalStatus']
for col in list_col: 
    print('{} :{} ' . format(col.upper(),data[col].unique()))
# Out:
# PRODUCT :['TM195' 'TM498' 'TM798']
# GENDER :['Male' 'Female']
# MARITALSTATUS :['Single' 'Partnered']

# %% [markdown]
# **Categorical/object type variables.**
#
# - *There are 3 categories in 'Product' column*
# - *There are 2 categories in 'Gender' column*
# - *There are 2 categories in 'MaritalStatus' column*

# %% [markdown]
# **Checking for duplicate entries in the data**

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
#  - *There is no missing values in any column*

# %% [markdown]
# **Let's check the statistical summary of the data.**

# %%
data.describe().T
# Out:
#             count      mean       std       min       25%       50%       75%  \
# Age       180.000    28.789     6.943    18.000    24.000    26.000    33.000
# Education 180.000    15.572     1.617    12.000    14.000    16.000    16.000
# Usage     180.000     3.456     1.085     2.000     3.000     3.000     4.000
# Fitness   180.000     3.311     0.959     1.000     3.000     3.000     4.000
# Income    180.000 53719.578 16506.684 29562.000 44058.750 50596.500 58668.000
# Miles     180.000   103.194    51.864    21.000    66.000    94.000   114.750
#
#                  max
# Age           50.000
# Education     21.000
# Usage          7.000
# Fitness        5.000
# Income    104581.000
# Miles        360.000

# %% [markdown]
# -  *Average Age of treadmill user is 28.78 years. Median aged of user is 26 years old, ranging from 18 to 50*
# -  *75% Education and median year is 16. The minimum is  12 and maximum is 21 years of education*
# -  *The average treadmill use is 3.45 and minimum usage is 1 time a week and maximum of 5 times a week*
# -  *The fitness  rating by the customer ranging from 1-5 and median of 5*
# -  *The average income of the customers 53719. Aprox. Minimum  29K and maximum 104K *
# -  *The mean of miles is 103 per week, while the median is 94*

# %% [markdown]
# ### Univariate Analysis

# %% [markdown]
# **Let's check the distribution for numerical columns.**

# %%
sns.histplot(data=data,x='Product')
plt.title('Product Sales by catergory')
plt.ylim(0,90)
plt.xlabel('Product')
plt.ylabel('Frequency')
plt.xticks(rotation=90);
plt.show()

# %%
data['Product'].value_counts()
# Out:
# TM195    80
# TM498    60
# TM798    40
# Name: Product, dtype: int64

# %%
# Percentage of each type
data['Product'].value_counts(normalize=True)
# Out:
# TM195   0.444
# TM498   0.333
# TM798   0.222
# Name: Product, dtype: float64

# %% [markdown]
# - *Product TM195 is used by 44.4% customer, TM498 is used by 33.33% and TM798 is used by 22.2% customer*

# %%
#Average Income of customer buying each model
data.groupby('Product')['Income'].mean()
# Out:
# Product
# TM195   46418.025
# TM498   48973.650
# TM798   75441.575
# Name: Income, dtype: float64

# %% [markdown]
# - *The TM195 and TM498 are more affordable for average income level of around 47000, but TM798 product is mostly purchased by high income level over 75000*

# %%
#Average age of customer buying each model
data.groupby('Product')['Age'].mean()
# Out:
# Product
# TM195   28.550
# TM498   28.900
# TM798   29.100
# Name: Age, dtype: float64

# %% [markdown]
# - *Average age of use model TM195 is 28.55, TM498 is 28.90 and TM798 is 29.10*

# %% [markdown]
# **Create bins for columns.**

# %%
# using pd.cut() function to create bins
data['Miles_range'] = pd.cut(data['Miles'],bins=[0,50,100,150,200, 250, 300, 350 , 400 ],labels=['50','100','150', '200', '250', '300', '350', '400'], right = False)

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=data, x='Miles_range', hue= 'MaritalStatus');

# %% [markdown]
# - *300-400 mile range is run by partnered customer*

# %%
plt.figure(figsize=(12,8))
sns.countplot(data=data, x='Miles_range', hue= 'Gender');

# %% [markdown]
# - *Male ran 350-400 miles range but female ran maximum 300 miles range*

# %%
sns.boxplot(data=data, x='Miles')
plt.show()

# %% [markdown]
# - *Most male and female run 100 miles for both Single and Partnered group*
# - *More femlale run 100 miles than Men*
# - *More partnered people run 100 miles than Single people*
# - *There are some outlier after around 190 miles*

# %%
sns.boxplot(data=data, x='Education');
plt.show()

# %% [markdown]
# - *Education has min. and max. range of 12 to 18 years. The Median is same as 75% percentile at 16 years.*

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=data, x='Usage');

# %% [markdown]
# - *Most common usage of the treadmill is 3 times per week*

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=data, x='Fitness' , color='orange')
plt.title('Histogram: Fitness')
plt.xlabel('Fitness Score')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# - *Most customer score 3 for fitness*

# %% [markdown]
# ### Bivariate Analysis

# %%
sns.barplot(data=data,x='Product' , y= 'Income', hue = 'Gender')
plt.title('Product Sales by catergory')
plt.xticks(rotation=90);
plt.show()

# %% [markdown]
# - *TM798 is purchased by higher income level around 75000, other two products are purchased by around 47000 income level for both male and Female*
# - *Male has higher income than Female*

# %%
# creating a line plot
sns.lineplot(data = data,  x = 'Usage', y = 'Fitness' , hue = 'Product', ci=False);
plt.show()

# %% [markdown]
# - *For TM195 and TM498 model, the fitness improved with Usage of treadmill from 2 to 5 times a week*
# - *For TM798 Model the Fitness starts 5 initially with the usage of 2 times a week, then it decreased till Usage of 4 times a week. But the Fitness is showing improvement after usage of 4 time upto 7 times*

# %%
# creating a line plot
sns.lineplot(data = data , x = 'Education' , y = 'Income' , ci=False);
plt.show()

# %% [markdown]
# - *Income is higher for higher educated people*

# %%
plt.figure(figsize=(10,5))
sns.heatmap(data.corr(),annot=True,cmap='Spectral',vmin=-1,vmax=1)
plt.show()

# %% [markdown]
# - *There is some correlation between Age and Income*
# - *Education and Income has also some correlation*
# - *Usage has very high correlation with Miles, and  also has some correlation with Income and Fitness score of the customer*
# - *Fitness is also highly correlated (0.79) with Miles *
# - *Miles and Income has some correlation of 0.54*

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,x='Usage',y='Miles')
plt.show()

# %% [markdown]
# - *With the Usage of treadmill the Miles increased*

# %%
# sns.lmplot(data=data, x='Age',y='Miles' , hue ='Gender' , height=5,aspect=2 ,ci=False )
sns.lmplot(data = data , x = 'Education' , y = 'Income' , hue = 'MaritalStatus', ci=False );
plt.show()

# %% [markdown]
# - *Partnered people with higher Education has more income than the single people*
# - *Less Education has less income level*

# %%
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,x='Income',y='Age')
plt.show()

# %% [markdown]
# - *Age increased with the increase of income*

# %%
g = sns.FacetGrid(data, col= "Product")
g.map(sns.histplot, "Education");

# %% [markdown]
# - *Customer of Education years 14 and 16 purchased  TM195 and TM498 model*
# - *Customer of Education years 16 and 18 purchased TM798 model*

# %% [markdown]
# **Pairplot**
# * A **pairplot** shows the relationship between two numeric variables for each pair of columns in the dataset.

# %%
sns.pairplot(data=data[['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles' ]] );

# %% [markdown]
# **We can set *corner=True* to plot only the lower triangle of a pairplot of Male and Female categories.**

# %%
sns.pairplot(data=data, vars=['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles'], hue='Gender',  corner=True);

# %% [markdown]
# - *Pairplot is showing the same observation and correlation as heatmap plot*

# %%
sns.jointplot(data=data, x='Age', y='Education', color = 'purple', kind= 'hex');

# %% [markdown]
# - *The Age between 20 to 40 years has the Education of 14 to 16 years*

# %% [markdown]
# ### Multivariate Analysis

# %%
plt.figure(figsize=(15,7))
sns.catplot(x='Usage', y='Income', col='Gender', hue='Product' , kind="bar", data = data );

# %% [markdown]
# - *TM798 product has more usage (5, 6, 7  times a week) for male than female*
# - *TM195 model is used 5 times a week by female than Male*
# - *Male are using TM498 model 4 times a week but female are using 5 times a week*
# - *Male has more income than female*

# %%
plt.figure(figsize=(15,7))
sns.catplot(x='Gender', y='Income', col='MaritalStatus', hue='Product' , kind="bar", data = data )

# %% [markdown]
# - *Partnered male purchased TM195 more than single male*
# - *Single female purchased TM498 more than Single male*
# - *Single Male purchased more TM798 than single female*
# - *Partnered Female purchased more TM798 than Partnered Male*

# %% [markdown]
# ### **Outlier Detection and Treatment**

# %% [markdown]
# **Let's visualize all the outliers present in data together**

# %%
# outlier detection using boxplot
# selecting the numerical columns of data 
numeric_columns = ['Age', 'Education', 'Usage', 'Fitness', 'Income', 'Miles' ]
plt.figure(figsize=(15, 12))

for i, variable in enumerate(numeric_columns):
    plt.subplot(4, 4, i + 1)
    plt.boxplot(data[variable], whis=1.5)
    plt.tight_layout()
    plt.title(variable)

plt.show()

# %% [markdown]
# - *Age, Education , Usage, Fitness, Income, Miles columns have outliers in the dataset*
# - *Age has very few Outliers which are genuine values*
# - *By treating the Outliers the data range will be changed, so we should keep the outlier in the data set to get more accurate analysis*
# - *Income and Miles have more outliers but Fitness, Usage and Education have very few outliers*

# %% [markdown]
# ## Conclusion and Recommendations

# %% [markdown]
# #### **Insights and Observation**
#
# - *Customer purchased TM195 model than other two model. TM498 is purchased more than TM798 model. So TM195 is most popular model*
# - *Product TM195 is used by 44.4% customer, TM498 is used by 33.33% and TM798 is used by 22.2% customer*
# -  *Age range 18 to 50 uses the treadmill , but average Age of treadmill user is 28.78 years. Median aged of user is 26 years old. So the younger people buy more treadmill*
# - *Female buys more TM195 and TM498 product than TM798 model*
# - *Female income is less than Male*
# - The Male uses more treadmill than Female*
# -  *The average income of the customers 53719. 75% customer income below 60K*
# - *TM798 model is mostly purchased by partnered people  with higher Income*
# - The most customer uses treadmill for 50-100 miles*

# %% [markdown]
# #### **Recommendations**
#
# - *Customer purchasing TM195 and TM498 model more with lower income. So we should market these two products for most people in general to increase the sell*
# - *The model TM798 can market and sell for high income group customer, So the this model should target as a luxury brand for the high end customer*
# - *Women are most likely buy TM195 and TM498 product. By adding more features to TM798 we can attract more female to buy TM798 model*
# - *Younger people age below 35 are mostly buy treadmill. By market research and more marketing campaign the older people can be attracted to buy treadmill*
# - *Female are buying less treadmill than male. So we can do some marketing during womens special days to attract more female.*
# - *we should do more research on all three product to include more feature to attract all Age, Gender and Marital status group*

# %%
! pip install nbconvert
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
! jupyter nbconvert --to html /content/1_Project___Cardio_Good_Fitness__Quazi_Nahida_Sultana_.ipynb
# Out:
# [NbConvertApp] Converting notebook /content/1_Project___Cardio_Good_Fitness__Quazi_Nahida_Sultana_.ipynb to html
# [NbConvertApp] Writing 1035141 bytes to /content/1_Project___Cardio_Good_Fitness__Quazi_Nahida_Sultana_.html
